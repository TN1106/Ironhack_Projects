# %% [markdown]
# # Yelp Restaurant Scraper - Web Scraping Project

# %% [markdown]
# ### Tom Nunziata 2019.06.03

# %%
#Define function that recieves parsed content and scrapes the content for the data we're interested in.

def YelpParser(content):
    
    #VERSION 2.0
    soup = BeautifulSoup(content)
    Block = [i for i in soup.select('div.largerScrollablePhotos__373c0__3FEIJ')]
    
    Total_Names= [i.text for i in soup.select('h3>a')]
    Names= [i.text for i in soup.select('h3>a') if 'adredir' not in i.get('href')] #Removing Sponsored Content
    #print(f'Number of Sponsored listings to remove: {len(Total_Names)} - {len(Names)} = {len(Total_Names)-len(Names)} ')
    
    link1 = 'https://www.yelp.com'
    Ratings = []
    Reviews = []
    Costs = []
    Style = []
    Address_Block = []
    Links = []
    
    for i in range(0, len(Total_Names)):
        if Total_Names[i] in Names:
            
            #Grab Ratings:
            try:
                rate = Block[i].div.div.span.div['aria-label']
                Ratings.append(float(rate.split(' ')[0]))
            except IndexError:
                Ratings.append(None)
    
            #Grab Number of Reviews
            try:
                rev = ((Block[i].div.find_all('div'))[0].find_all('div'))[3].text
                Reviews.append(int(rev.split(' ')[0]))     
            except IndexError:
                Reviews.append(0.0)
                
            #Grab Cost Scale
            try:
                cost = Block[i].find_all('span',{'class':'priceRange__373c0__2DY87'})[0].text
                Costs.append(len(cost))
            except IndexError:
                Costs.append(None)
                
            #Grab Cuisine Style
            try:
                style = Block[i].find_all('a',{'class':'link-size--default__373c0__1skgq'})
                style_lists = [[j.text] for j in style]
                Style.append(style_lists)
        
            except IndexError:
                Style.append(['Unknown'])
            
            #Grab Address Block
        
            add = [i.getText(separator=u' | ') for i in soup.select('div.container__373c0__19wDx')][i]
            if len(add) > 0:
                Address_Block.append(add)    
            else:
                Address_Block.append('Unknown')
                
            
            #Grab Link
            try:
                link2 = Block[i].a.get('href')
                Links.append(link1+link2)   
            except IndexError:
                Links.append(['No Link Available'])
    
    info = getAddress(Address_Block)

    Phone_Numbers = info[0]
    Address = info[1]
    Area = info[2]
    
    #print('Names- ',len(Names),'Rating - ',len(Ratings),'Reviews - ',len(Reviews),'Cost - ',len(Costs),'Cuisine - ',len(Style),
    #      'Address - ',len(Address),'Area - ',len(Area),'Phone #s - ',len(Phone_Numbers),'Link - ',len(Links))
    
    return {'Names':Names, 'Rating_(Max=5)':Ratings, 'Reviews':Reviews, 'Cost_(Max=4)': Costs, 'Type_cuisine':Style, 
            'Address': Address, 'Area': Area, 'Phone_Number': Phone_Numbers, 'Link': Links}

# %%
#Define function that recieves parsed content and scrapes the content for the data we're interested in.

def getAddress(Address_total):
    Addy_Split = [i.split(' | ') for i in Address_total]
    Address = []
    Phone_Number = []
    Area = []

    for i in Addy_Split:
        if len(i) >=3:
            Phone_Number.append(i[0])
            Area.append(i[-1])
            Address.append((''.join(i[1:-1])))
        elif 0 < len(i) <= 2:
            
            if i[0].replace(' ','').replace('+','').replace('(','').replace(')','').replace('-','').isdigit() == False:
                Phone_Number.append('Unknown')
                
                if len(i) == 2:
                    Address.append((''.join(i[0:-1])))
                    Area.append(i[-1])
                else:
                    Address.append((''.join(i[1:])))
                    Area.append(' ')
                
            else:
                Phone_Number.append(i[0])
                Address.append((''.join(i[1:])))
                Area.append(' ')


    return (Phone_Number, Address, Area)

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

class YelpSpider:

    def __init__(self, pages_to_scrape=1, sleep_interval=-1, content_parser=None):
        
        self.pages_to_scrape = pages_to_scrape
        self.sleep_interval = sleep_interval
        self.content_parser = content_parser
        self.data_frame = pd.DataFrame([])

        
    '''
    Define method that retrieves information from the website and handles potential access issues.
    '''    
    def scrape_url(self, url):
        try:
            response = requests.get(url, timeout = 10)

            #Check response status
            if response.status_code < 300:    
                result = self.content_parser(response.content)
                self.BuildDataFrame(result)
                
            elif 500 > response.status_code >= 400:
                return('Forbidden Access')
            else:
                return('Server Connection Error')

        except requests.exceptions.SSLError:
            print('Warning, no certificate')
            return('no certificate')
        except requests.exceptions.Timeout:
            print("Timeout")
            return('timeout')
        except requests.exceptions.TooManyRedirects:    #Built-in 30 max redirects
            print('Too many redirects')
            return('redirect exceeded')
        except requests.exceptions.RequestException as e:
            return(f'unknown error: {e}')
   
    """
    Function builds new data frame for page and appends it to the existing self.data_frame
    """
    def BuildDataFrame(self, r):
        
        self.data_frame = self.data_frame.append(pd.DataFrame(r) ,ignore_index=True)
        
        
    """
    Method exports Data Frame to CSV
    """
    def ExportDFtoCSV(self, City):
        
        self.data_frame.to_csv(f'YelpData-{City}.csv',index=False)   
    
    """
    After the class is initiated, call this function to start the scraping jobs.
    
    """
    def kickstart(self):
        
        city_in = input('Enter a city:')
        state_country_in = input("Enter city's state (if in USA), or city's country (otherwise):")
        
        City = city_in.replace(' ','%20')
        State_Country = state_country_in.replace(' ','%20')
        
        if self.sleep_interval >0:
            import time
            for i in range(1, self.pages_to_scrape+1):
                n = (i-1)*30
                self.scrape_url(f'https://www.yelp.com/search?find_desc=Restaurants&find_loc={City}%2C%20{State_Country}&start={n}')
                time.sleep(self.sleep_interval)
        else:
            for i in range(1, self.pages_to_scrape+1):
                n = (i-1)*30
                self.scrape_url(f'https://www.yelp.com/search?find_desc=Restaurants&find_loc={City}%2C%20{State_Country}&start={n}')
               
        display(self.data_frame)    #Displays final data frame when loop is completed
        self.ExportDFtoCSV(City)         #Exports final data frame to CSV.

# %%
'''
Execute
'''

PAGES_TO_SCRAPE = 3 # how many webpages to scrape

# Initiate the YelpSpider class
my_yelp_spider = YelpSpider(PAGES_TO_SCRAPE, content_parser=YelpParser)

# Start scraping jobs
my_yelp_spider.kickstart()
# Out:
# Enter a city:Paris
# Enter city's state (if in USA), or city's country (otherwise):France
#                                  Names  Rating_(Max=5)  Reviews  Cost_(Max=4)  \
# 0        Le Comptoir de la Gastronomie             4.5      935           2.0
# 1                             Angelina             4.0     1226           3.0
# 2                       La Coïncidence             4.5      447           2.0
# 3                 Bistro des Augustins             4.5      356           2.0
# 4           Le Potager du Père Thierry             4.5      404           2.0
# 5                       Baguett’s Café             4.5      172           2.0
# 6                      Les Antiquaires             4.5      281           2.0
# 7                     L’Avant Comptoir             4.5      591           2.0
# 8                 Le Temps des Cerises             4.5      314           2.0
# 9                     L’As du Fallafel             4.5     1709           1.0
# 10               Le Bistro du Périgord             4.5      336           3.0
# 11                          Chez Janou             4.0      498           2.0
# 12                         Café Louise             4.5       57           2.0
# 13                           Eggs & Co             4.0      337           2.0
# 14                         La Jacobine             4.5      254           3.0
# 15                   Pain Vin Fromages             4.5      232           2.0
# 16                   Bistrot Richelieu             4.0      158           2.0
# 17                   La Cave Gourmande             4.5      299           2.0
# 18               Le Bistrot des Vosges             4.5       51           2.0
# 19                        Les Artizans             5.0       21           2.0
# 20     Enza & Famiglia Trattoria Pasta             5.0       34           2.0
# 21                           L’Epicure             4.5      153           4.0
# 22              La Droguerie du Marais             4.5      188           1.0
# 23                            Le Rubis             4.0       48           1.0
# 24  Claus - La Table du Petit-Déjeuner             4.5      245           3.0
# 25             Crêperie Saint Eustache             4.5       47           2.0
# 26                       Café de Paris             4.0       39           2.0
# 27                     Les Philosophes             3.5      310           2.0
# 28                        Maison Rouge             4.0       18           1.0
# 29                        Les Papilles             4.5      238           3.0
# ..                                 ...             ...      ...           ...
# 60                Les Petites Bouchées             4.5       65           2.0
# 61                     Le Petit Canard             4.5      172           2.0
# 62                           Framboise             4.0      198           2.0
# 63                             Fraîche             4.5      100           3.0
# 64                        Les Cocottes             4.0      502           3.0
# 65                            Sanukiya             4.5      315           2.0
# 66                        Chez Fernand             4.5      177           3.0
# 67                 La Fontaine de Mars             4.5      249           3.0
# 68                    Le Prince Racine             5.0        3           NaN
# 69                      La Cordonnerie             4.5       75           3.0
# 70                         Les Embruns             4.5       59           2.0
# 71                      Café des Anges             4.0      145           2.0
# 72                             Baroche             4.0      176           2.0
# 73              La Petite Périgourdine             4.0      108           2.0
# 74                            Lockwood             4.0      105           2.0
# 75                          Café Blanc             4.5       23           NaN
# 76               Le Comptoir du Marais             5.0        4           2.0
# 77                    Le Volant Basque             4.5      216           2.0
# 78                         Breizh Café             4.0      406           2.0
# 79                        Le Black Dog             4.0      114           2.0
# 80                    Au Petit Village             5.0       11           NaN
# 81                         Café Louise             4.0       72           2.0
# 82            Le Relais de l’Entrecôte             4.0      395           3.0
# 83                         La Régalade             4.5       83           3.0
# 84                          Pedzouille             5.0       17           2.0
# 85               Les P’tites Indécises             4.0      147           2.0
# 86                             Pascade             4.5       74           3.0
# 87                      Crêperie Genia             4.5       39           1.0
# 88             La Crêperie de Josselin             4.0      410           2.0
# 89                              Girafe             4.5       16           NaN
#
#                                          Type_cuisine  \
# 0                                          [[French]]
# 1   [[Breakfast & Brunch], [Tea Rooms], [Patisseri...
# 2                                          [[French]]
# 3                            [[Bistros], [Wine Bars]]
# 4                                          [[French]]
# 5                     [[Cafes], [Breakfast & Brunch]]
# 6                                          [[French]]
# 7                         [[Tapas Bars], [Wine Bars]]
# 8                                         [[Bistros]]
# 9                 [[Kosher], [Sandwiches], [Falafel]]
# 10                                        [[Bistros]]
# 11                           [[Bistros], [Provencal]]
# 12                                 [[Bars], [French]]
# 13                             [[Breakfast & Brunch]]
# 14                            [[Tea Rooms], [French]]
# 15                                         [[Fondue]]
# 16                              [[French], [Bistros]]
# 17                                         [[French]]
# 18                                        [[Bistros]]
# 19                [[Patisserie/Cake Shop], [Bistros]]
# 20                                        [[Italian]]
# 21                   [[French], [Breakfast & Brunch]]
# 22                                      [[Creperies]]
# 23              [[Brasseries], [French], [Wine Bars]]
# 24                    [[Breakfast & Brunch], [Cafes]]
# 25                                      [[Creperies]]
# 26                                     [[Brasseries]]
# 27                                 [[French], [Bars]]
# 28     [[French], [Breakfast & Brunch], [Brasseries]]
# 29                           [[Wine Bars], [Bistros]]
# ..                                                ...
# 60                       [[Tapas Bars], [Gastropubs]]
# 61                                         [[French]]
# 62                                      [[Creperies]]
# 63                                         [[French]]
# 64                                         [[French]]
# 65                                       [[Japanese]]
# 66                                         [[French]]
# 67                                         [[French]]
# 68                  [[Cafes], [Brasseries], [French]]
# 69                                         [[French]]
# 70                            [[French], [Creperies]]
# 71                                         [[French]]
# 72                                     [[Brasseries]]
# 73                           [[French], [Brasseries]]
# 74  [[Tapas/Small Plates], [Cocktail Bars], [Break...
# 75   [[French], [Coffee & Tea], [Breakfast & Brunch]]
# 76                                     [[Brasseries]]
# 77                                         [[Basque]]
# 78                  [[Creperies], [Cafes], [Seafood]]
# 79                              [[Bars], [Argentine]]
# 80                                         [[French]]
# 81                            [[Cafes], [Brasseries]]
# 82                                         [[French]]
# 83                                         [[French]]
# 84                         [[Bistros], [Steakhouses]]
# 85                                         [[French]]
# 86                                         [[French]]
# 87                                      [[Creperies]]
# 88                       [[Creperies], [Gluten-Free]]
# 89                              [[French], [Seafood]]
#
#                                   Address  \
# 0                       34 rue Montmartre
# 1                       226 rue de Rivoli
# 2                           15 rue Mesnil
# 3            39 quai des Grands Augustins
# 4                 16 rue des Trois Frères
# 5                     33 rue de Richelieu
# 6                           13 rue du Bac
# 7   Located in Hotel Relais Saint Germain
# 8                   31 rue de la Cerisaie
# 9                      34 rue des Rosiers
# 10                   71 rue Saint-Jacques
# 11                   2 rue Roger Verlomme
# 12          8 rue Croix des Petits Champs
# 13                 11 rue Bernard Palissy
# 14         59-61 rue Saint-André des Arts
# 15               3 rue Geoffroy-l'Angevin
# 16                       45 Rue Richelieu
# 17                     96 rue des Martyrs
# 18                     31 bd Beaumarchais
# 19                  30 rue de Montorgueil
# 20                    89 rue Saint-Honoré
# 21            Located in Le Bristol Paris
# 22                     56 rue des Rosiers
# 23          10 rue du Marché Saint-Honoré
# 24           14 rue Jean-Jacques Rousseau
# 25                           2 rue Sauval
# 26                     3 rue de l'Échelle
# 27               28 rue Vieille du Temple
# 28            12-14 rue de la Ferronnerie
# 29                      30 rue Gay-Lussac
# ..                                    ...
# 60                 4 rue du Roi de Sicile
# 61                   19 rue Henri Monnier
# 62                      7 rue de Ponthieu
# 63                      8 rue Vicq d'Azir
# 64                135 rue Saint-Dominique
# 65                     9 rue d'Argenteuil
# 66                        9 rue Christine
# 67                129 rue Saint-Dominique
# 68              22 rue Monsieur le Prince
# 69                      20 rue Saint Roch
# 70                          8 rue de Lyon
# 71                  66 rue de la Roquette
# 72                      101 rue la Boétie
# 73                      39 rue des Ecoles
# 74                       73 rue d'Aboukir
# 75         10 rue Croix des Petits Champs
# 76                       24 rue de Rivoli
# 77                 13 rue Béatrix Dussane
# 78              109 rue Vieille du Temple
# 79                    26 rue des Lombards
# 80                          06 rue Coypel
# 81                   155 bd Saint Germain
# 82                20 bis rue Saint Benoît
# 83                   106 rue Saint-Honoré
# 84        66 rue du Faubourg Poissonnière
# 85                     2 rue des 3 bornes
# 86                          14 rue Daunou
# 87                     15 rue de la Harpe
# 88                    67 rue Montparnasse
# 89                   1 place du Trocadéro
#
#                                    Area    Phone_Number  \
# 0                   Châtelet/Les Halles  01 42 33 31 32
# 1                         Place Vendôme  01 42 60 82 00
# 2                        Trocadéro/Iéna  01 47 55 96 44
# 3                    Saint-Michel/Odéon  01 43 54 04 41
# 4                            Montmartre  01 53 28 26 20
# 5          Palais Royal/Musée du Louvre  09 54 83 04 86
# 6                         Musée d'Orsay  01 42 61 08 36
# 7                    Saint-Michel/Odéon  01 42 38 47 55
# 8                              Bastille  01 42 72 08 63
# 9                                Marais  01 48 87 63 60
# 10                   Saint-Michel/Odéon  01 43 29 67 49
# 11                             Bastille  01 42 72 28 41
# 12         Palais Royal/Musée du Louvre  01 42 60 22 44
# 13               Saint-Germain-Des-Prés  01 45 44 02 52
# 14                   Saint-Michel/Odéon  01 46 34 15 95
# 15                            Beaubourg  01 42 74 07 52
# 16         Palais Royal/Musée du Louvre  01 42 60 19 16
# 17                           Montmartre  01 46 06 10 34
# 18                             Bastille  01 42 72 94 85
# 19                  Châtelet/Les Halles  01 40 28 44 74
# 20                  Châtelet/Les Halles  01 40 41 06 25
# 21                                 8ème  01 53 43 43 40
# 22                               Marais         Unknown
# 23                        Place Vendôme  01 42 61 03 34
# 24         Palais Royal/Musée du Louvre  01 42 33 55 10
# 25                  Châtelet/Les Halles  01 40 28 40 39
# 26         Palais Royal/Musée du Louvre  01 42 60 84 26
# 27                               Marais  01 48 87 49 64
# 28                  Châtelet/Les Halles  01 42 21 19 33
# 29                    Sorbonne/Panthéon  01 43 25 20 79
# ..                                  ...             ...
# 60                               Marais  01 44 61 49 96
# 61                              Pigalle  01 49 70 07 95
# 62  Avenue Montaigne/Faubourg St-Honoré  01 74 64 02 79
# 63              Colonel Fabien/Goncourt  01 40 37 54 23
# 64            Tour Eiffel/Champ de Mars  01 45 50 10 28
# 65         Palais Royal/Musée du Louvre  01 42 60 52 61
# 66                   Saint-Michel/Odéon  01 43 25 18 55
# 67            Tour Eiffel/Champ de Mars  01 47 05 46 44
# 68                   Saint-Michel/Odéon  01 43 29 83 35
# 69         Palais Royal/Musée du Louvre  01 42 60 17 42
# 70                                Bercy  01 43 46 88 62
# 71                         Ledru-Rollin  01 47 00 00 63
# 72                                 8ème  01 43 59 69 57
# 73                    Sorbonne/Panthéon  01 43 26 33 35
# 74            Grands Boulevards/Sentier  01 77 32 97 21
# 75         Palais Royal/Musée du Louvre  01 42 33 55 85
# 76                               Marais  09 50 77 86 78
# 77                                15ème  01 45 75 27 67
# 78                          Marais Nord  01 42 72 13 77
# 79                            Beaubourg  01 42 71 22 27
# 80                  Port Royal/Gobelins  01 43 37 08 57
# 81               Saint-Germain-Des-Prés  01 42 22 88 98
# 82               Saint-Germain-Des-Prés  01 45 49 16 00
# 83                  Châtelet/Les Halles  01 42 21 92 40
# 84   Strasbourg-St Denis/Bonne Nouvelle  09 86 40 42 42
# 85                 Oberkampf/Parmentier  01 43 57 26 00
# 86                        Place Vendôme  01 42 60 11 00
# 87                   Saint-Michel/Odéon         Unknown
# 88                         Montparnasse  01 43 20 93 50
# 89                       Trocadéro/Iéna  01 40 62 70 61
#
#                                                  Link
# 0   https://www.yelp.com/biz/le-comptoir-de-la-gas...
# 1   https://www.yelp.com/biz/angelina-paris?osq=Re...
# 2   https://www.yelp.com/biz/la-co%C3%AFncidence-p...
# 3   https://www.yelp.com/biz/bistro-des-augustins-...
# 4   https://www.yelp.com/biz/le-potager-du-p%C3%A8...
# 5   https://www.yelp.com/biz/baguetts-caf%C3%A9-pa...
# 6   https://www.yelp.com/biz/les-antiquaires-paris...
# 7   https://www.yelp.com/biz/l-avant-comptoir-pari...
# 8   https://www.yelp.com/biz/le-temps-des-cerises-...
# 9   https://www.yelp.com/biz/l-as-du-fallafel-pari...
# 10  https://www.yelp.com/biz/le-bistro-du-p%C3%A9r...
# 11  https://www.yelp.com/biz/chez-janou-paris?osq=...
# 12  https://www.yelp.com/biz/caf%C3%A9-louise-pari...
# 13  https://www.yelp.com/biz/eggs-et-co-paris?osq=...
# 14  https://www.yelp.com/biz/la-jacobine-paris?osq...
# 15  https://www.yelp.com/biz/pain-vin-fromages-par...
# 16  https://www.yelp.com/biz/bistrot-richelieu-par...
# 17  https://www.yelp.com/biz/la-cave-gourmande-par...
# 18  https://www.yelp.com/biz/le-bistrot-des-vosges...
# 19  https://www.yelp.com/biz/les-artizans-paris?os...
# 20  https://www.yelp.com/biz/enza-et-famiglia-trat...
# 21  https://www.yelp.com/biz/l-epicure-paris-2?osq...
# 22  https://www.yelp.com/biz/la-droguerie-du-marai...
# 23  https://www.yelp.com/biz/le-rubis-paris-2?osq=...
# 24  https://www.yelp.com/biz/claus-la-table-du-pet...
# 25  https://www.yelp.com/biz/cr%C3%AAperie-saint-e...
# 26  https://www.yelp.com/biz/caf%C3%A9-de-paris-pa...
# 27  https://www.yelp.com/biz/les-philosophes-paris...
# 28  https://www.yelp.com/biz/maison-rouge-paris?os...
# 29  https://www.yelp.com/biz/les-papilles-paris?os...
# ..                                                ...
# 60  https://www.yelp.com/biz/les-petites-bouch%C3%...
# 61  https://www.yelp.com/biz/le-petit-canard-paris...
# 62  https://www.yelp.com/biz/framboise-paris-20?os...
# 63  https://www.yelp.com/biz/fra%C3%AEche-paris-2?...
# 64  https://www.yelp.com/biz/les-cocottes-paris?os...
# 65  https://www.yelp.com/biz/sanukiya-paris?osq=Re...
# 66  https://www.yelp.com/biz/chez-fernand-paris?os...
# 67  https://www.yelp.com/biz/la-fontaine-de-mars-p...
# 68  https://www.yelp.com/biz/le-prince-racine-pari...
# 69  https://www.yelp.com/biz/la-cordonnerie-paris-...
# 70  https://www.yelp.com/biz/les-embruns-paris-2?o...
# 71  https://www.yelp.com/biz/caf%C3%A9-des-anges-p...
# 72  https://www.yelp.com/biz/baroche-paris-3?osq=R...
# 73  https://www.yelp.com/biz/la-petite-p%C3%A9rigo...
# 74  https://www.yelp.com/biz/lockwood-paris?osq=Re...
# 75  https://www.yelp.com/biz/caf%C3%A9-blanc-paris...
# 76  https://www.yelp.com/biz/le-comptoir-du-marais...
# 77  https://www.yelp.com/biz/le-volant-basque-pari...
# 78  https://www.yelp.com/biz/breizh-caf%C3%A9-pari...
# 79  https://www.yelp.com/biz/le-black-dog-paris?os...
# 80  https://www.yelp.com/biz/au-petit-village-pari...
# 81  https://www.yelp.com/biz/caf%C3%A9-louise-pari...
# 82  https://www.yelp.com/biz/le-relais-de-l-entrec...
# 83  https://www.yelp.com/biz/la-r%C3%A9galade-pari...
# 84  https://www.yelp.com/biz/pedzouille-paris?osq=...
# 85  https://www.yelp.com/biz/les-p-tites-ind%C3%A9...
# 86  https://www.yelp.com/biz/pascade-paris?osq=Res...
# 87  https://www.yelp.com/biz/cr%C3%AAperie-genia-p...
# 88  https://www.yelp.com/biz/la-cr%C3%AAperie-de-j...
# 89  https://www.yelp.com/biz/girafe-paris?osq=Rest...
#
# [90 rows x 9 columns]
